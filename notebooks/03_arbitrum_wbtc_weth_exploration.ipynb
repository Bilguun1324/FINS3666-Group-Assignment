# %% [markdown]
# # Arbitrum WBTC/WETH
#
# This notebook now uses the shared `second_level_markets.py` pipeline. It either builds a real one-week, second-by-second reserve reconstruction on compatible on-chain markets, or writes an explicit blocker manifest when that is not honest to do.

# %%
from __future__ import annotations

from pathlib import Path
import sys

import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import Markdown, display

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == 'notebooks':
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from second_level_markets import SECOND_LEVEL_MARKETS, dataset_summary_frame, load_or_build_second_level_dataset

MARKET_KEY = '03_arbitrum_wbtc_weth'
MARKET_SPEC = SECOND_LEVEL_MARKETS[MARKET_KEY]
REFRESH_SECOND_LEVEL_DATA = False

market_dataset = load_or_build_second_level_dataset(MARKET_KEY, project_root=PROJECT_ROOT, refresh=REFRESH_SECOND_LEVEL_DATA)

summary_rows = [
    {'field': 'chain_name', 'value': MARKET_SPEC.chain_name},
    {'field': 'pair_label', 'value': MARKET_SPEC.pair_label},
    {'field': 'sample_window_days', 'value': MARKET_SPEC.sample_window_days},
    {'field': 'state_frequency', 'value': '1s'},
    {'field': 'supported', 'value': MARKET_SPEC.supported},
    {'field': 'primary_trade_size_base', 'value': MARKET_SPEC.primary_trade_size_base},
    {'field': 'trade_sizes_base', 'value': ', '.join(str(x) for x in MARKET_SPEC.trade_sizes_base)},
    {'field': 'notes', 'value': ' | '.join(MARKET_SPEC.notes)},
]

display(pd.DataFrame(summary_rows))
display(dataset_summary_frame(market_dataset))

if market_dataset['status'] == 'blocked':
    display(pd.DataFrame({'blocker': market_dataset['blockers']}))
else:
    display(market_dataset['pair_metadata'])
    display(market_dataset['size_sensitivity'])
    display(pd.DataFrame(market_dataset['qc_report'].items(), columns=['check', 'value']))
# Out:
#                      field                                              value
# 0               chain_name                                           Arbitrum
# 1               pair_label                                          WBTC/WETH
# 2       sample_window_days                                                  7
# 3          state_frequency                                                 1s
# 4                supported                                               True
# 5  primary_trade_size_base                                               0.01
# 6         trade_sizes_base    0.0005, 0.001, 0.0025, 0.005, 0.01, 0.025, 0.05
# 7                    notes  This is a real second-level reserve reconstruc...
#                       field                                              value
# 0                    status                                          supported
# 1                chain_name                                           Arbitrum
# 2                pair_label                                          WBTC/WETH
# 3        sample_window_days                                                  7
# 4           state_frequency                                                 1s
# 5          window_start_utc                   2026-04-11T02:22:57.579898+00:00
# 6            window_end_utc                   2026-04-18T02:22:57.579898+00:00
# 7   primary_trade_size_base                                               0.01
# 8            event_log_rows                                                387
# 9           pool_state_rows                                            1203521
# 10           arb_label_rows                                             599867
# 11         positive_seconds                                                  0
# 12         max_net_edge_bps                                       -2817.344034
# 13                qc_passed                                               True
# 14                    notes  This is a real second-level reserve reconstruc...
#        role                  dex                                pair_address  \
# 0  arb_pair   sushiswap_arbitrum  0x515e252b2b5c22b4b2b6df66c2ebeea871aa4d69
# 1  arb_pair  uniswap_v2_arbitrum  0x8c1d83a25ee2da1643a5d937562682b1ac6c856b
#
#                               factory_address event_style  \
# 0  0xc35dadb65012ec5796536bd9864ed8773abc74c4  uniswap_v2
# 1  0xf1d7cc64fb4452f05c498126312ebe29f30fbcf9  uniswap_v2
#
#                                        token0  \
# 0  0x2f2a2543b76a4166549f7aab2e75bef0aefc5b0f
# 1  0x2f2a2543b76a4166549f7aab2e75bef0aefc5b0f
#
#                                        token1 base_symbol  \
# 0  0x82af49447d8a07e3bd95bd0d56f35241523fbab1        WBTC
# 1  0x82af49447d8a07e3bd95bd0d56f35241523fbab1        WBTC
#
#                            base_token_address  base_token_decimals  \
# 0  0x2f2a2543b76a4166549f7aab2e75bef0aefc5b0f                    8
# 1  0x2f2a2543b76a4166549f7aab2e75bef0aefc5b0f                    8
#
#   quote_symbol                         quote_token_address  \
# 0         WETH  0x82af49447d8a07e3bd95bd0d56f35241523fbab1
# 1         WETH  0x82af49447d8a07e3bd95bd0d56f35241523fbab1
#
#    quote_token_decimals  base_is_token0  fee_bps  fee_rate
# 0                    18            True     30.0     0.003
# 1                    18            True     30.0     0.003
#    trade_size_base  observed_seconds  gross_positive_seconds  \
# 0           0.0005            599867                       0
# 1           0.0010            599867                       0
# 2           0.0025            599867                       0
# 3           0.0050            599867                       0
# 4           0.0100            599867                       0
# 5           0.0250            599867                       0
# 6           0.0500            599867                       0
#
#    net_positive_seconds  max_net_profit_quote  mean_net_profit_quote  \
# 0                     0             -0.000276              -0.000396
# 1                     0             -0.001183              -0.001393
# 2                     0             -0.007256              -0.007749
# 3                     0             -0.026913              -0.028436
# 4                     0             -0.097244              -0.101539
# 5                     0             -0.495339              -0.510302
# 6                     0             -1.670558              -1.722389
#
#    max_net_edge_bps  mean_net_edge_bps
# 0       -173.203574        -245.131567
# 1       -364.406942        -430.616638
# 2       -882.996970        -952.232026
# 3      -1611.557479       -1719.616490
# 4      -2817.344034       -2971.429148
# 5      -5196.644906       -5377.511287
# 6      -7260.890087       -7399.095035
#                             check  \
# 0                   schema_errors
# 1           duplicate_swap_events
# 2  monotonic_timestamp_violations
# 3           non_positive_reserves
# 4              pool_state_gaps_1s
# 5               stale_state_nulls
# 6                          passed
#
#                                                value
# 0  {'swaps_raw': [], 'pool_state_1s': [], 'arb_la...
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4  {'sushiswap_arbitrum': 0, 'uniswap_v2_arbitrum...
# 5                                                  0
# 6                                               True

# %%
if market_dataset["status"] == "blocked":
    display(Markdown("""## Blocked

This market is intentionally left without synthetic second-level output. The blocker list above explains what additional infrastructure or venue coverage would be required."""))
else:
    arb_labels = market_dataset["arb_labels"]
    opportunity_windows = market_dataset["opportunity_windows"]
    key_columns = [
        "timestamp",
        "buy_dex",
        "sell_dex",
        "trade_size_base",
        "gross_edge_bps",
        "fee_cost_bps",
        "gas_cost_quote",
        "net_edge_quote",
        "net_edge_bps",
        "opportunity_flag",
    ]
    best_seconds = arb_labels.sort_values("net_edge_bps", ascending=False).head(20)
    display(best_seconds.loc[:, [column for column in key_columns if column in best_seconds.columns]])
    display(opportunity_windows.head(20))
# Out:
#                        timestamp             buy_dex             sell_dex  \
# 165121 2026-04-13 00:14:58+00:00  sushiswap_arbitrum  uniswap_v2_arbitrum
# 169379 2026-04-13 01:25:56+00:00  sushiswap_arbitrum  uniswap_v2_arbitrum
# 169377 2026-04-13 01:25:54+00:00  sushiswap_arbitrum  uniswap_v2_arbitrum
# 169376 2026-04-13 01:25:53+00:00  sushiswap_arbitrum  uniswap_v2_arbitrum
# 169375 2026-04-13 01:25:52+00:00  sushiswap_arbitrum  uniswap_v2_arbitrum
# 169374 2026-04-13 01:25:51+00:00  sushiswap_arbitrum  uniswap_v2_arbitrum
# 169373 2026-04-13 01:25:50+00:00  sushiswap_arbitrum  uniswap_v2_arbitrum
# 169372 2026-04-13 01:25:49+00:00  sushiswap_arbitrum  uniswap_v2_arbitrum
# 169371 2026-04-13 01:25:48+00:00  sushiswap_arbitrum  uniswap_v2_arbitrum
# 169370 2026-04-13 01:25:47+00:00  sushiswap_arbitrum  uniswap_v2_arbitrum
# 169369 2026-04-13 01:25:46+00:00  sushiswap_arbitrum  uniswap_v2_arbitrum
# 169368 2026-04-13 01:25:45+00:00  sushiswap_arbitrum  uniswap_v2_arbitrum
# 169367 2026-04-13 01:25:44+00:00  sushiswap_arbitrum  uniswap_v2_arbitrum
# 169366 2026-04-13 01:25:43+00:00  sushiswap_arbitrum  uniswap_v2_arbitrum
# 169365 2026-04-13 01:25:42+00:00  sushiswap_arbitrum  uniswap_v2_arbitrum
# 169364 2026-04-13 01:25:41+00:00  sushiswap_arbitrum  uniswap_v2_arbitrum
# 169363 2026-04-13 01:25:40+00:00  sushiswap_arbitrum  uniswap_v2_arbitrum
# 169362 2026-04-13 01:25:39+00:00  sushiswap_arbitrum  uniswap_v2_arbitrum
# 169361 2026-04-13 01:25:38+00:00  sushiswap_arbitrum  uniswap_v2_arbitrum
# 169360 2026-04-13 01:25:37+00:00  sushiswap_arbitrum  uniswap_v2_arbitrum
#
#         trade_size_base  gross_edge_bps  fee_cost_bps  gas_cost_quote  \
# 165121             0.01    -2770.591514     46.624788        0.000004
# 169379             0.01    -2770.591514     46.624788        0.000004
# 169377             0.01    -2770.591514     46.624788        0.000004
# 169376             0.01    -2770.591514     46.624788        0.000004
# 169375             0.01    -2770.591514     46.624788        0.000004
# 169374             0.01    -2770.591514     46.624788        0.000004
# 169373             0.01    -2770.591514     46.624788        0.000004
# 169372             0.01    -2770.591514     46.624788        0.000004
# 169371             0.01    -2770.591514     46.624788        0.000004
# 169370             0.01    -2770.591514     46.624788        0.000004
# 169369             0.01    -2770.591514     46.624788        0.000004
# 169368             0.01    -2770.591514     46.624788        0.000004
# 169367             0.01    -2770.591514     46.624788        0.000004
# 169366             0.01    -2770.591514     46.624788        0.000004
# 169365             0.01    -2770.591514     46.624788        0.000004
# 169364             0.01    -2770.591514     46.624788        0.000004
# 169363             0.01    -2770.591514     46.624788        0.000004
# 169362             0.01    -2770.591514     46.624788        0.000004
# 169361             0.01    -2770.591514     46.624788        0.000004
# 169360             0.01    -2770.591514     46.624788        0.000004
#
#         net_edge_quote  net_edge_bps  opportunity_flag
# 165121       -0.097244  -2817.344034             False
# 169379       -0.097244  -2817.344034             False
# 169377       -0.097244  -2817.344034             False
# 169376       -0.097244  -2817.344034             False
# 169375       -0.097244  -2817.344034             False
# 169374       -0.097244  -2817.344034             False
# 169373       -0.097244  -2817.344034             False
# 169372       -0.097244  -2817.344034             False
# 169371       -0.097244  -2817.344034             False
# 169370       -0.097244  -2817.344034             False
# 169369       -0.097244  -2817.344034             False
# 169368       -0.097244  -2817.344034             False
# 169367       -0.097244  -2817.344034             False
# 169366       -0.097244  -2817.344034             False
# 169365       -0.097244  -2817.344034             False
# 169364       -0.097244  -2817.344034             False
# 169363       -0.097244  -2817.344034             False
# 169362       -0.097244  -2817.344034             False
# 169361       -0.097244  -2817.344034             False
# 169360       -0.097244  -2817.344034             False
# Empty DataFrame
# Columns: [start_timestamp, end_timestamp, seconds, buy_dex, sell_dex, max_net_edge_bps, mean_net_edge_bps, max_net_profit_quote, mean_net_profit_quote]
# Index: []

# %%
if market_dataset['status'] == 'blocked':
    display(Markdown('No second-level plot is generated for blocked markets.'))
else:
    pool_state = market_dataset['pool_state'].copy()
    arb_labels = market_dataset['arb_labels'].copy()
    opportunity_windows = market_dataset['opportunity_windows'].copy()

    display(Markdown('## Visual Checks'))
    fig, axes = plt.subplots(2, 1, figsize=(16, 10), constrained_layout=True)

    price_plot = (
        pool_state.assign(plot_timestamp=pool_state['timestamp'].dt.floor('5min'))
        .groupby(['plot_timestamp', 'dex'], as_index=False)
        .agg(mid_price_quote_per_base=('mid_price_quote_per_base', 'last'))
    )
    for dex, group in price_plot.groupby('dex'):
        axes[0].plot(group['plot_timestamp'], group['mid_price_quote_per_base'], label=dex, linewidth=1.5)
    axes[0].set_title('5-minute sampled mid-price by venue')
    axes[0].set_ylabel('Quote per base')
    axes[0].legend()

    if not opportunity_windows.empty:
        best_window = opportunity_windows.iloc[0]
        mask = (
            (arb_labels['timestamp'] >= best_window['start_timestamp'])
            & (arb_labels['timestamp'] <= best_window['end_timestamp'])
        )
        plot_scores = arb_labels.loc[mask].sort_values('timestamp')
        axes[1].set_title('Top positive window net edge')
    else:
        plot_scores = arb_labels.nlargest(min(400, len(arb_labels)), 'net_edge_bps').sort_values('timestamp')
        axes[1].set_title('Top scored seconds by net edge')

    axes[1].plot(plot_scores['timestamp'], plot_scores['net_edge_bps'], linewidth=1.5)
    axes[1].axhline(0.0, color='black', linestyle='--', linewidth=1)
    axes[1].set_ylabel('Net edge (bps)')
    axes[1].set_xlabel('Timestamp (UTC)')
    plt.show()
# Out:
# ## Visual Checks

# %%
import json

manifest_path = PROJECT_ROOT / 'outputs' / MARKET_SPEC.slug / 'metadata' / 'dataset_manifest.json'
display(Markdown(f'## Manifest\n\nSaved manifest: `{manifest_path}`'))
if manifest_path.exists():
    manifest_payload = json.loads(manifest_path.read_text())
    display(pd.json_normalize(manifest_payload, sep='.', max_level=1).T.reset_index().rename(columns={'index': 'field', 0: 'value'}))
# Out:
# ## Manifest
#
# Saved manifest: `/Users/bilguuntsolmon/Desktop/main/uni/finance/fins3666/assignment3/outputs/arbitrum_wbtc_weth/metadata/dataset_manifest.json`
#                           field  \
# 0                        status
# 1                   market_slug
# 2                     chain_key
# 3                    chain_name
# 4                    pair_label
# 5            sample_window_days
# 6               state_frequency
# 7                     gas_units
# 8             priority_fee_gwei
# 9                         notes
# 10                     blockers
# 11             generated_at_utc
# 12             window_start_utc
# 13               window_end_utc
# 14                  start_block
# 15                    end_block
# 16                  rpc_env_var
# 17                   rpc_source
# 18                pair_metadata
# 19      primary_trade_size_base
# 20        size_sensitivity_rows
# 21             positive_seconds
# 22             max_net_edge_bps
# 23                    qc_passed
# 24            base_token.symbol
# 25           base_token.address
# 26          base_token.decimals
# 27           quote_token.symbol
# 28          quote_token.address
# 29         quote_token.decimals
# 30             gas_token.symbol
# 31            gas_token.address
# 32           gas_token.decimals
# 33              rows.event_logs
# 34          rows.events_curated
# 35               rows.swaps_raw
# 36           rows.pool_state_1s
# 37  rows.gas_reference_state_1s
# 38           rows.arb_labels_1s
#
#                                                 value
# 0                                           supported
# 1                                  arbitrum_wbtc_weth
# 2                                            arbitrum
# 3                                            Arbitrum
# 4                                           WBTC/WETH
# 5                                                   7
# 6                                                  1s
# 7                                              220000
# 8                                                 0.0
# 9   [This is a real second-level reserve reconstru...
# 10                                                 []
# 11                   2026-04-18T02:24:46.907472+00:00
# 12                   2026-04-11T02:22:57.579898+00:00
# 13                   2026-04-18T02:22:57.579898+00:00
# 14                                          451225544
# 15                                          453638725
# 16                                   ARBITRUM_RPC_URL
# 17                                public_rpc_fallback
# 18  [{'role': 'arb_pair', 'dex': 'sushiswap_arbitr...
# 19                                               0.01
# 20                                                  7
# 21                                                  0
# 22                                       -2817.344034
# 23                                               True
# 24                                               WBTC
# 25         0x2f2a2543b76a4166549f7aab2e75bef0aefc5b0f
# 26                                                  8
# 27                                               WETH
# 28         0x82af49447d8a07e3bd95bd0d56f35241523fbab1
# 29                                                 18
# 30                                               WETH
# 31         0x82af49447d8a07e3bd95bd0d56f35241523fbab1
# 32                                                 18
# 33                                                387
# 34                                                387
# 35                                                191
# 36                                            1203521
# 37                                                  0
# 38                                             599867
